# %% [markdown]
# # Dataset
#
# Use this notebook for **barebones exploratory checks** on the Kaggle Formula 1 CSVs before building a DNF model.
#
# CSV files live in `data/` at the project root (`dsc148-f1-project/`). **Prefer starting Jupyter or the notebook kernel with the project root as the working directory.** If the kernel cwd is `notebooks/` instead, the next cell still resolves `../data` when `data/` is not found in the cwd.

# %%
# !pip install gdown
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [filelock]
#    ------------- -------------------------- 1/3 [filelock]
#    ------------- -------------------------- 1/3 [filelock]
#    ------------- -------------------------- 1/3 [filelock]
#    -------------------------- ------------- 2/3 [gdown]
#    -------------------------- ------------- 2/3 [gdown]
#    -------------------------- ------------- 2/3 [gdown]
#    ---------------------------------------- 3/3 [gdown]
#
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install gdown
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gdown
import zipfile
import os

if not os.path.exists("../data/") or not os.listdir("../data/"):
    os.makedirs("../data/", exist_ok=True)
    gdown.download("https://drive.google.com/uc?id=1-tr5mnzHvhITodbDKmefVOz926ZU5zOO", "../data/archive.zip", quiet=False)
    with zipfile.ZipFile("../data/archive.zip", "r") as z:
        z.extractall("../data/")
    print("Done!")
else:
    print("Data already exists, skipping download.")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-tr5mnzHvhITodbDKmefVOz926ZU5zOO
# To: c:\Users\ericg\ds_school\dsc148\data\archive.zip
# 100%|██████████| 6.59M/6.59M [00:00<00:00, 16.5MB/s]
# Done!

# %%
from pathlib import Path
import pandas as pd


def resolve_data_dir() -> Path:
    for p in (Path("data"), Path("..") / "data"):
        if (p / "results.csv").exists():
            return p.resolve()
    raise FileNotFoundError(
        "Could not find data/results.csv. Place Kaggle CSVs in data/ "
        "or run Jupyter with the project root as the working directory."
    )

DATA_DIR = resolve_data_dir()
assert (DATA_DIR / "results.csv").exists(), "results.csv missing"
print(f"DATA_DIR = {DATA_DIR}")
# Out:
# DATA_DIR = C:\Users\ericg\ds_school\dsc148\dsc148-f1-project\data

# %% [markdown]
# ## CSV inventory

# %%
csv_paths = sorted(DATA_DIR.glob("*.csv"))
for p in csv_paths:
    print(f"{p.name}\t{p.stat().st_size / 1024:.1f} KiB")
# Out:
# circuits.csv	9.9 KiB
# constructor_results.csv	214.2 KiB
# constructor_standings.csv	309.8 KiB
# constructors.csv	17.1 KiB
# driver_standings.csv	863.1 KiB
# drivers.csv	92.2 KiB
# lap_times.csv	17209.4 KiB
# pit_stops.csv	433.3 KiB
# qualifying.csv	454.3 KiB
# races.csv	160.5 KiB
# results.csv	1681.6 KiB
# seasons.csv	4.5 KiB
# sprint_results.csv	24.2 KiB
# status.csv	2.1 KiB

# %% [markdown]
# ## Core tables

# %%
drivers = pd.read_csv(DATA_DIR /'drivers.csv')
lap_times = pd.read_csv(DATA_DIR / 'lap_times.csv')
results = pd.read_csv(DATA_DIR / "results.csv")
status = pd.read_csv(DATA_DIR / "status.csv")
races = pd.read_csv(DATA_DIR / "races.csv")
drivers = pd.read_csv(DATA_DIR / "drivers.csv")
constructors = pd.read_csv(DATA_DIR / "constructors.csv")
constructor_results = pd.read_csv(DATA_DIR / "constructor_results.csv")

for name, df in [
    ("results", results),
    ("status", status),
    ("races", races),
    ("drivers", drivers),
    ("constructors", constructors),
    ("lap_times", lap_times),
]:
    print(f"\n=== {name} === shape {df.shape}")
    display(df.head())
    display(df.dtypes.to_frame("dtype"))
# Out:
# === results === shape (26759, 18)
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# ...

# %% [markdown]
# ## Results + status (DNF-oriented join)

# %%
results_status = results.merge(
    status, on="statusId", how="left", validate="m:1"
)
print(results_status.shape)
display(results_status.head())
display(results_status["status"].value_counts().head(20))
# Out:
# (26759, 19)
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId    status
# ...

# %% [markdown]
# # Exploring the dataset

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
print("\n" + "="*70)
print("FORMULA 1 HISTORICAL DATABASE - SCOPE AND OVERVIEW")
print("="*70)

# Time span
year_min = races['year'].min()
year_max = races['year'].max()
print(f"\nTIME SPAN:")
print(f"  - First race season: {year_min}")
print(f"  - Most recent race season: {year_max}")
print(f"  - Total years covered: {year_max - year_min + 1} seasons")

# Race metrics
total_races = len(races)
total_results = len(results)
print(f"\nRACE METRICS:")
print(f"  - Total races in dataset: {total_races}")
print(f"  - Total race entries (results): {total_results}")
print(f"  - Average entries per race: {total_results / total_races:.1f}")
# Out:
# ...
# FORMULA 1 HISTORICAL DATABASE - SCOPE AND OVERVIEW
# ...
#
# TIME SPAN:
#   - First race season: 1950
#   - Most recent race season: 2024
#   - Total years covered: 75 seasons
#
# RACE METRICS:
#   - Total races in dataset: 1125
#   - Total race entries (results): 26759
#   - Average entries per race: 23.8

# %%
print("\n" + "="*70)
print("FORMULA 1 HISTORICAL DATABASE - SCOPE AND OVERVIEW CONT.")
print("="*70)

# Driver and team metrics
unique_drivers = drivers['driverId'].nunique()
unique_constructors = constructors['constructorId'].nunique()

print(f"\nDRIVERS & TEAMS:")
print(f"  - Total drivers in database: {unique_drivers}")
print(f"  - Total constructors in database: {unique_constructors}")


# Lap time metrics
total_lap_records = len(lap_times)
races_with_lap_data = lap_times['raceId'].nunique()
print(f"\nLAP TIME DATA:")
print(f"  - Total lap time records: {total_lap_records:,}")
print(f"  - Races with lap data: {races_with_lap_data}")

# Status data
print(f"\nRESULT STATUS CODES:")
print(f"  - Unique status categories: {len(status)}")
print(f"  - Common statuses:")
for idx, row in status.head(10).iterrows():
    print(f"    - {row['status']}")
# Out:
# ...
# FORMULA 1 HISTORICAL DATABASE - SCOPE AND OVERVIEW CONT.
# ...
#
# DRIVERS & TEAMS:
#   - Total drivers in database: 861
#   - Total constructors in database: 212
#
# LAP TIME DATA:
#   - Total lap time records: 589,081
#   - Races with lap data: 544
#
# RESULT STATUS CODES:
#   - Unique status categories: 139
#   - Common statuses:
#     - Finished
#     - Disqualified
#     - Accident
#     - Collision
#     - Engine
#     - Gearbox
#     - Transmission
#     - Clutch
#     - Hydraulics
#     - Electrical

# %% [markdown]
# ### How many unique F1 drivers have there been?

# %%
total_drivers = drivers['driverId'].nunique()
print(f"Total unique F1 drivers in history: {total_drivers}")

drivers_with_races = results['driverId'].nunique()
print(f"Drivers who participated in at least one race: {drivers_with_races}")

print("\nTop 10 drivers by number of races:")
driver_race_counts = results.groupby('driverId').size().sort_values(ascending=False).head(10)
driver_names = drivers.set_index('driverId')[['forename', 'surname']]
for driver_id, count in driver_race_counts.items():
    name = f"{driver_names.loc[driver_id, 'forename']} {driver_names.loc[driver_id, 'surname']}"
    print(f"  {name}: {count} races")
# Out:
# Total unique F1 drivers in history: 861
# Drivers who participated in at least one race: 861
#
# Top 10 drivers by number of races:
#   Fernando Alonso: 404 races
#   Lewis Hamilton: 356 races
#   Kimi Räikkönen: 352 races
#   Rubens Barrichello: 326 races
#   Jenson Button: 309 races
#   Michael Schumacher: 308 races
#   Sebastian Vettel: 300 races
#   Sergio Pérez: 283 races
#   Felipe Massa: 271 races
#   Daniel Ricciardo: 257 races

# %% [markdown]
# ### How many different teams have there been?

# %%
total_constructors = constructors['constructorId'].nunique()
constructors_with_races = results['constructorId'].nunique()

print(f"Total unique F1 constructors/teams in history: {total_constructors}")
print(f"Teams that participated in at least one race: {constructors_with_races}")

# Show some examples
print("\nTop 15 teams by number of races:")
team_race_counts = results.groupby('constructorId').size().sort_values(ascending=False).head(15)
team_names = constructors.set_index('constructorId')[['name']]
for team_id, count in team_race_counts.items():
    name = team_names.loc[team_id, 'name']
    print(f"  {name}: {count} races")
# Out:
# Total unique F1 constructors/teams in history: 212
# Teams that participated in at least one race: 211
#
# Top 15 teams by number of races:
#   Ferrari: 2439 races
#   McLaren: 1923 races
#   Williams: 1676 races
#   Tyrrell: 881 races
#   Team Lotus: 871 races
#   Sauber: 837 races
#   Red Bull: 788 races
#   Renault: 787 races
#   Minardi: 672 races
#   Brabham: 662 races
#   Mercedes: 652 races
#   Ligier: 611 races
#   Arrows: 590 races
#   BRM: 562 races
#   Toro Rosso: 536 races

# %% [markdown]
# ### How does the constructors makeup look over the years?

# %%
import matplotlib.pyplot as plt
results_with_year = results.merge(races[['raceId', 'year']], on='raceId')
results_with_year = results_with_year.merge(constructors[['constructorId', 'name']], on='constructorId')

constructors_per_year = results_with_year.groupby('year')['constructorId'].nunique()

print("Number of constructors competing per year:")
print(f"Minimum: {constructors_per_year.min()} (in {constructors_per_year.idxmin()})")
print(f"Maximum: {constructors_per_year.max()} (in {constructors_per_year.idxmax()})")
print(f"Mean: {constructors_per_year.mean():.1f}")

fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(constructors_per_year.index, constructors_per_year.values, linewidth=2, marker='o', markersize=4)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Number of Constructors', fontsize=12)
ax.set_title('Number of F1 Constructors Over Time', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nTop 5 years with most constructors:")
print(constructors_per_year.sort_values(ascending=False).head())
# Out:
# Number of constructors competing per year:
# Minimum: 10 (in 2003)
# Maximum: 26 (in 1959)
# Mean: 14.8
# Top 5 years with most constructors:
# year
# 1959    26
# 1952    25
# 1950    24
# 1951    24
# 1960    23
# Name: constructorId, dtype: int64

# %% [markdown]
# ### Have the average lap times gone down over the years?

# %%
lap_times_with_year = lap_times.merge(races[['raceId', 'year']], on='raceId')

lap_times_with_year_clean = lap_times_with_year[lap_times_with_year['milliseconds'].notna()]
lap_times_with_year_clean = lap_times_with_year_clean[lap_times_with_year_clean['milliseconds'] > 0]

avg_lap_time_per_year = lap_times_with_year_clean.groupby('year')['milliseconds'].mean()

avg_lap_time_seconds = avg_lap_time_per_year / 1000

print("Average lap time statistics:")
print(f"Fastest average lap time: {avg_lap_time_seconds.min():.2f} seconds (in {avg_lap_time_seconds.idxmin()})")
print(f"Slowest average lap time: {avg_lap_time_seconds.max():.2f} seconds (in {avg_lap_time_seconds.idxmax()})")
print(f"Overall change: {avg_lap_time_seconds.iloc[-1] - avg_lap_time_seconds.iloc[0]:.2f} seconds")

fig, ax = plt.subplots(figsize=(15, 6))
ax.plot(avg_lap_time_seconds.index, avg_lap_time_seconds.values, linewidth=2, marker='o', markersize=4, color='#e74c3c')
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Average Lap Time (seconds)', fontsize=12)
ax.set_title('Average Lap Times Over Time (Lower is Faster)', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nNote: Faster lap times in recent years indicate improvements in car technology and track conditions.")
# Out:
# Average lap time statistics:
# Fastest average lap time: 87.73 seconds (in 2002)
# Slowest average lap time: 108.67 seconds (in 2011)
# Overall change: -0.27 seconds
# Note: Faster lap times in recent years indicate improvements in car technology and track conditions.

# %% [markdown]
# ### How has the average number of races changed over the years?

# %%
races_per_year = races.groupby('year').size()

print("Number of races per year statistics:")
print(f"Minimum races in a season: {races_per_year.min()} (in {races_per_year.idxmin()})")
print(f"Maximum races in a season: {races_per_year.max()} (in {races_per_year.idxmax()})")
print(f"Average races per season: {races_per_year.mean():.1f}")
print(f"Most recent season ({races_per_year.index[-1]}): {races_per_year.iloc[-1]} races")

# Visualization
fig, ax = plt.subplots(figsize=(15, 6))
ax.bar(races_per_year.index, races_per_year.values, color='#2ecc71', alpha=0.7)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Number of Races', fontsize=12)
ax.set_title('Number of F1 Races Per Season Over Time', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

print(f"\nTrend: F1 has expanded from {races_per_year.iloc[0]} races in {races_per_year.index[0]} to {races_per_year.iloc[-1]} races in {races_per_year.index[-1]}")
# Out:
# Number of races per year statistics:
# Minimum races in a season: 7 (in 1950)
# Maximum races in a season: 24 (in 2024)
# Average races per season: 15.0
# Most recent season (2024): 24 races
# Trend: F1 has expanded from 7 races in 1950 to 24 races in 2024

# %% [markdown]
# ## Looking if the earliest lap at which the race leader is the eventual winner at least 70% of the time decreased in Formula 1 races from 1996–2024?

# %%
races = races[['raceId', 'year']]
lap_times.drop(columns=['milliseconds', 'time'], inplace=True)

df = lap_times.merge(races, on='raceId', how='left')

df.to_csv('../data/laps_and_finish_times.csv', index=False)

# %%
results = []

for race_id in df['raceId'].unique():
    test = df[df['raceId'] == race_id]
    laps = test['lap'].max()

    winner = test[(test['lap'] == laps) & (test['position'] == 1)]['driverId']
    
    if winner.empty:
        continue
    
    winner_id = winner.values[0]
    df1 = test[test['driverId'] == winner_id]
    
    earliest_winning_lap = laps 
    for i in range(laps, 0, -1):
        lap_data = df1[df1['lap'] == i]['position'].values
        if len(lap_data) > 0 and lap_data[0] == 1:
            earliest_winning_lap = i
        else:
            break
    
    year = df1['year'].iloc[0]
    results.append({
        'year': year,
        'raceId': race_id,
        'winnerId': winner_id,
        'earliest_winning_lap': earliest_winning_lap,
        'total_laps': laps
    })

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#      year  raceId  winnerId  earliest_winning_lap  total_laps
# 0    2011     841        20                    17          58
# 1    2011     842        20                    27          56
# 2    2011     843         1                    52          56
# 3    2011     844        20                    13          58
# 4    2011     845        20                    50          66
# ..    ...     ...       ...                   ...         ...
# 539  2024    1140       832                     9          71
# 540  2024    1141       830                    43          69
# 541  2024    1142       847                    14          50
# 542  2024    1143       830                     1          57
# 543  2024    1144       846                     1          58
#
# [544 rows x 5 columns]

# %% [markdown]
# note this plot probably needs to be recreated in excel or google sheets

# %%
import matplotlib.pyplot as plt 


res = results_df.groupby('year')['earliest_winning_lap'].mean()
fig, ax = plt.subplots(figsize=(16, 5))
res.plot(kind='line', ax=ax, marker='o', linewidth=2, markersize=3, color='steelblue')

# Labels above each point
for x, y in zip(res.index, res.values):
    ax.annotate(f'{y:.1f}', xy=(x, y), xytext=(0, 15),
                textcoords='offset points', ha='center', fontsize=15, color='#444')

ax.set_title('Average Earliest Winning Lap by Year', fontsize=20, pad=20)
ax.set_xlabel('') 
ax.set_ylabel('')
ax.set_xlim(res.index.min() - 0.3, res.index.max() + 0.3)

ax.spines[['top', 'right', 'left']].set_visible(False)
ax.yaxis.set_visible(False)
ax.tick_params(axis='x', length=0) 
ax.grid(False)
ax.set_xticks(res.index)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Compute the grouped mean
res = results_df.groupby('year')['earliest_winning_lap'].mean()

# Prepare data
x = res.index.values
y = res.values

# Fit linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
regression_line = slope * x + intercept

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(x, y, color='steelblue', zorder=5, label='Yearly Mean')
ax.plot(x, regression_line, color='tomato', linewidth=2,
        label=f'Regression (slope={slope:.4f}, R²={r_value**2:.3f})')

ax.set_xlabel('Year')
ax.set_ylabel('Earliest Winning Lap (mean)')
ax.set_title('Earliest Winning Lap Over Time')
ax.legend()
plt.tight_layout()
plt.show()

print(f"Slope:     {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"R²:        {r_value**2:.4f}")
print(f"P-value:   {p_value:.4f}")
# Out:
# Slope:     -0.4120
# Intercept: 859.6893
# R²:        0.3522
# P-value:   0.0007

# %% [markdown]
# As the seasons goes on it seems that the race winner is decided earlier in the race. This something interesting to know and we wonder if this might have something to do with the DNFs.

# %% [markdown]
# ## DNF label (foundations — target ~May 9)
#
# **Working definition (refine as a group):** a driver result counts as a successful **finish** when `statusId == 1`, which maps to `"Finished"` in `status.csv`. Everything else is labeled **`dnf_binary = 1`** here (one not-finished bucket). That includes disqualifications, accidents, DNS, and so on. Split those into finer labels later if you move to multiclass.
#
# Document any rule changes in your report Methods section.

# %%
FINISHED_STATUS_ID = 1

dnf_binary = (results_status["statusId"] != FINISHED_STATUS_ID).astype(int)
print("dnf_binary value counts:\n", dnf_binary.value_counts())
print("Overall DNF-ish rate:", dnf_binary.mean().round(4))
# Out:
# dnf_binary value counts:
#  statusId
# 1    19085
# 0     7674
# Name: count, dtype: int64
# Overall DNF-ish rate: 0.7132

# %% [markdown]
# ## Time-based train / test split
#
# **Working split (tune with your group):** train on races with `year < TEST_YEAR_START`, test on `year >= TEST_YEAR_START`. This avoids random splits that leak future seasons into the past. Adjust the cutoff to match how much recent data you want held out.

# %%
races_year = pd.read_csv(DATA_DIR / "races.csv", usecols=["raceId", "year"])
labeled = results_status.merge(races_year, on="raceId", how="left", validate="m:1")

TEST_YEAR_START = 2018
train_mask = labeled["year"] < TEST_YEAR_START
test_mask = labeled["year"] >= TEST_YEAR_START

print("Train rows:", int(train_mask.sum()), "Test rows:", int(test_mask.sum()))
print("Train DNF rate:", float(dnf_binary[train_mask].mean()))
print("Test DNF rate:", float(dnf_binary[test_mask].mean()))
# Out:
# Train rows: 23780 Test rows: 2979
# Train DNF rate: 0.7473086627417999
# Test DNF rate: 0.44108761329305135
